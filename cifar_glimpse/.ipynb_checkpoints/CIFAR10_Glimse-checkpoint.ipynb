# %% [markdown]
# # Full CIFAR-10 in a Glimpse
# In this notebook we build a composite image out of the CIFAR-10 catalog. We would like to represent a dog image using only dogs images, etc.

# %%
# Run some setup code for this notebook.
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# Load the raw CIFAR-10 data.
sys.path.append('../../data_science/cs231n/assignment1')
from cs231n.data_utils import load_CIFAR10
cifar10_dir = '../../data_science/cs231n/assignment1/cs231n/datasets/cifar-10-python/cifar-10-batches-py/'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
X = np.concatenate([X_train,X_test])
y = np.concatenate([y_train,y_test])
print(X.shape)
print(y.shape)
# Out:
# (60000, 32, 32, 3)
# (60000,)

# %%
# X_flat: make vectors for each channel in each image: 
X_flat = X.reshape([X.shape[0],-1,3])
print(X_flat.shape)
# img_char: 
img_char = np.empty([X.shape[0],3])
for img_num in range(X.shape[0]):
    img_char[img_num] = np.median(X_flat[img_num],axis=0)
print(img_char.shape)
# Out:
# (60000, 1024, 3)
# (60000, 3)

# %% [markdown]
# Example image:

# %%
img_num=7
img = X_train[img_num]
cat = y_train[img_num]
plt.figure(figsize=[3,3])
plt.imshow(img.astype('uint8'));

# %%
timg_char=img_char[y==cat].copy()
tX = X[y==cat]
imsize=32
com_img = np.empty([imsize*32,imsize*32,3])
for ix in range(imsize):
    for iy in range(imsize):
        idx = np.argmin(((timg_char-img[ix,iy,:])**2).sum(axis=1))
        timg_char[idx]=np.zeros([3,])
        com_img[ix*32:(ix+1)*32,iy*32:(iy+1)*32]=tX[idx]

plt.figure(figsize=[3,3])
plt.imshow(com_img.astype('uint8'));

# %%
plt.figure(figsize=[10,2])
for i in range(5):
    print('Number of image left: {}'.format((timg_char.sum(axis=1)>0).sum()))
    com_img = np.empty([imsize*32,imsize*32,3])
    for ix in range(imsize):
        for iy in range(imsize):
            idx = np.argmin(((timg_char-img[ix,iy,:])**2).sum(axis=1))
            timg_char[idx]=np.zeros([3,])
            com_img[ix*32:(ix+1)*32,iy*32:(iy+1)*32]=tX[idx]

    plt.subplot(1,5,i+1)
    plt.imshow(com_img.astype('uint8'));
# Out:
# Number of image left: 4975
# Number of image left: 3970
# Number of image left: 3017
# Number of image left: 2078
# Number of image left: 1159

# %%
print('Number of image left: {}'.format((timg_char.sum(axis=1)>0).sum()))
# Out:
# Number of image left: 263
